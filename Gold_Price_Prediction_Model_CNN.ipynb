# %% [markdown]
# # load local data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import tensorflow as tf
import keras
from keras.models import Sequential
# from keras.layers.core import Dense, Activation, Flatten
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout
from keras.optimizers import Adam
from keras.layers import Conv1D, Conv2D, MaxPooling2D
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score, accuracy_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import csv
import collections
from scipy.stats import zscore
from datetime import datetime
import matplotlib.pyplot as plt

# %%
column_names=["Date", "Time", "Open", "High", "Low", "Close", "Volume"]

files = [file for file in os.listdir('./data/XAUUSD/')]
files
# Out:
# ['DAT_MT_XAUUSD_M1_2015.csv',
#  'DAT_MT_XAUUSD_M1_2019.csv',
#  'DAT_MT_XAUUSD_M1_2014.csv',
#  'DAT_MT_XAUUSD_M1_2018.csv',
#  'DAT_MT_XAUUSD_M1_2016.csv',
#  'DAT_MT_XAUUSD_M1_2012.csv',
#  'DAT_MT_XAUUSD_M1_2009.csv',
#  'DAT_MT_XAUUSD_M1_2021.csv',
#  'DAT_MT_XAUUSD_M1_2010.csv',
#  'DAT_MT_XAUUSD_M1_2020.csv',
#  'DAT_MT_XAUUSD_M1_2022.csv',
#  'DAT_MT_XAUUSD_M1_2011.csv',
#  'DAT_MT_XAUUSD_M1_2017.csv',
#  'DAT_MT_XAUUSD_M1_2013.csv']

# %% [markdown]
# # Loop throught all the data files and merge them into one CSV file

# %%
data = pd.DataFrame()

for file in files:
#     print(file)
    df = pd.read_csv("./data/XAUUSD/"+file, names=column_names)
    data = pd.concat([data, df])

data.to_csv("all_data.csv", index=False)

# %%
data = pd.read_csv("./all_data.csv")
data
# Out:
#                Date   Time     Open     High      Low    Close  Volume
# 0        2015.01.01  18:01  1184.13  1184.44  1184.04  1184.13       0
# 1        2015.01.01  18:02  1184.12  1184.41  1184.12  1184.41       0
# 2        2015.01.01  18:03  1184.53  1184.54  1184.32  1184.54       0
# 3        2015.01.01  18:04  1184.60  1184.60  1184.43  1184.51       0
# 4        2015.01.01  18:05  1184.46  1184.54  1184.46  1184.54       0
# ...             ...    ...      ...      ...      ...      ...     ...
# 4862461  2013.12.31  15:55  1202.29  1202.59  1202.28  1202.59       0
# 4862462  2013.12.31  15:56  1202.58  1202.74  1202.58  1202.68       0
# 4862463  2013.12.31  15:57  1202.67  1202.90  1202.67  1202.89       0
# 4862464  2013.12.31  15:58  1202.96  1203.11  1202.95  1203.05       0
# 4862465  2013.12.31  15:59  1203.34  1204.74  1203.34  1204.19       0
#
# [4862466 rows x 7 columns]

# %% [markdown]
# # Filter dataframe to produce only daily data from existing data

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%Y.%m.%d')
df = data.drop_duplicates(subset='Date')

# %%
df.head(3)
# Out:
#            Date   Time     Open     High      Low    Close  Volume
# 0    2015-01-01  18:01  1184.13  1184.44  1184.04  1184.13       0
# 347  2015-01-02  00:00  1184.69  1184.79  1184.48  1184.62       0
# 1360 2015-01-04  18:00  1187.01  1187.01  1186.65  1187.00       0

# %%
df = df.reset_index(drop=True) # use the date column as the index
df
# Out:
#            Date   Time     Open     High      Low    Close  Volume
# 0    2015-01-01  18:01  1184.13  1184.44  1184.04  1184.13       0
# 1    2015-01-02  00:00  1184.69  1184.79  1184.48  1184.62       0
# 2    2015-01-04  18:00  1187.01  1187.01  1186.65  1187.00       0
# 3    2015-01-05  00:00  1191.69  1192.09  1191.61  1191.70       0
# 4    2015-01-06  00:00  1206.55  1207.23  1206.55  1206.58       0
# ...         ...    ...      ...      ...      ...      ...     ...
# 4289 2013-12-26  06:09  1205.70  1205.70  1205.70  1205.70       0
# 4290 2013-12-27  00:00  1211.03  1211.15  1210.93  1211.06       0
# 4291 2013-12-29  18:00  1214.20  1214.60  1214.20  1214.45       0
# 4292 2013-12-30  00:00  1209.71  1209.72  1209.61  1209.63       0
# 4293 2013-12-31  00:00  1198.14  1198.59  1198.14  1198.48       0
#
# [4294 rows x 7 columns]

# %%
df = df.iloc[::-1] # This reverses the order of the dataframe rows

# %%
df.head(3)
# Out:
#            Date   Time     Open     High      Low    Close  Volume
# 4293 2013-12-31  00:00  1198.14  1198.59  1198.14  1198.48       0
# 4292 2013-12-30  00:00  1209.71  1209.72  1209.61  1209.63       0
# 4291 2013-12-29  18:00  1214.20  1214.60  1214.20  1214.45       0

# %%
df.shape
# Out:
# (4294, 7)

# %%
df = df.reset_index(drop=True) # reset index
df
# Out:
#            Date   Time     Open     High      Low    Close  Volume
# 0    2013-12-31  00:00  1198.14  1198.59  1198.14  1198.48       0
# 1    2013-12-30  00:00  1209.71  1209.72  1209.61  1209.63       0
# 2    2013-12-29  18:00  1214.20  1214.60  1214.20  1214.45       0
# 3    2013-12-27  00:00  1211.03  1211.15  1210.93  1211.06       0
# 4    2013-12-26  06:09  1205.70  1205.70  1205.70  1205.70       0
# ...         ...    ...      ...      ...      ...      ...     ...
# 4289 2015-01-06  00:00  1206.55  1207.23  1206.55  1206.58       0
# 4290 2015-01-05  00:00  1191.69  1192.09  1191.61  1191.70       0
# 4291 2015-01-04  18:00  1187.01  1187.01  1186.65  1187.00       0
# 4292 2015-01-02  00:00  1184.69  1184.79  1184.48  1184.62       0
# 4293 2015-01-01  18:01  1184.13  1184.44  1184.04  1184.13       0
#
# [4294 rows x 7 columns]

# %%
df = df.drop(columns=['Date', 'Time', 'Volume']) # drop unnecessary columns

# %%
df.head()
# Out:
#       Open     High      Low    Close
# 0  1198.14  1198.59  1198.14  1198.48
# 1  1209.71  1209.72  1209.61  1209.63
# 2  1214.20  1214.60  1214.20  1214.45
# 3  1211.03  1211.15  1210.93  1211.06
# 4  1205.70  1205.70  1205.70  1205.70

# %% [markdown]
# Lets take a look at closing price, its so rough

# %%
plt.figure(figsize=(10,10))
plt.plot(df['Close'])

# %%
# Normalization

scaler = MinMaxScaler(feature_range=(0,1))
df = scaler.fit_transform(df)

y_close = df[:,1]

# %%
plt.figure(figsize=(15,15))
plt.plot(y_close)
plt.show()

# %% [markdown]
# # Data splitting into training and testing data

# %%
ntrain = int(len(y_close)*0.8)

train = df[0:ntrain]
test  = df[ntrain:len(df)]

y_close_train = y_close[0:ntrain]
y_close_test  = y_close[ntrain:len(y_close)]

# %%
y_close_test.shape
# Out:
# (859,)

# %% [markdown]
# ## Here we construct the image

# %%
import numpy as np

def to_sequences(seq_size, data,close):
    x = []
    y = []

    for i in range(len(data)-seq_size-1):
        window = data[i:(i+seq_size)]
        after_window = close[i+seq_size]
        window = [[x] for x in window]
        x.append(window)
        y.append(after_window)

    return np.array(x),np.array(y)


timesteps = 10

x_train, y_train = to_sequences(timesteps, train, y_close_train)
x_test, y_test   = to_sequences(timesteps, test, y_close_test)

print("Shape of x_train: {}".format(x_train.shape))
print("Shape of x_test: {}".format(x_test.shape))
print("Shape of y_train: {}".format(y_train.shape))
print("Shape of y_test: {}".format(y_test.shape))
# Out:
# Shape of x_train: (3424, 10, 1, 4)
# Shape of x_test: (848, 10, 1, 4)
# Shape of y_train: (3424,)
# Shape of y_test: (848,)

# %%
x_train[0]
# Out:
# array([[[0.27742851, 0.27748271, 0.27798532, 0.27791878]],
#
#        [[0.28716594, 0.28685109, 0.28765797, 0.28732046]],
#
#        [[0.29094478, 0.29095871, 0.29152872, 0.29138469]],
#
#        [[0.28827687, 0.28805476, 0.28877113, 0.28852624]],
#
#        [[0.28379109, 0.28346736, 0.28436067, 0.28400668]],
#
#        [[0.27768941, 0.27752479, 0.27824675, 0.27799467]],
#
#        [[0.27969244, 0.27947759, 0.28016947, 0.28000992]],
#
#        [[0.28153557, 0.28281082, 0.28210063, 0.28307916]],
#
#        [[0.27582103, 0.27598444, 0.27637462, 0.27633356]],
#
#        [[0.29596077, 0.29568078, 0.29641142, 0.29609818]]])

# %%
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[2], x_train.shape[1],x_train.shape[3]))
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[2],x_test.shape[1],x_test.shape[3]))

# %%
print(x_train.shape)
# Out:
# (3424, 1, 10, 4)

# %%
x_train[0][0].shape
# Out:
# (10, 4)

# %% [markdown]
# ### Here is the image expected

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5)
ax1.imshow(x_train[0][0])
ax2.imshow(x_train[1][0])
ax3.imshow(x_train[2][0])
ax4.imshow(x_train[3][0])
ax5.imshow(x_train[4][0])

# %%
cnn = Sequential()
cnn.add(Conv2D(8, kernel_size = (1, 2), strides = (1, 1),  padding = 'valid',
               activation = 'relu', input_shape = (1,10,4)))
cnn.add(MaxPooling2D(pool_size = (1,2)))

cnn.add(Flatten())
cnn.add(Dense(64, activation="relu"))
cnn.add(Dropout(0.5))
cnn.add(Dense(1, activation="relu"))
cnn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 1, 9, 8)             │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 1, 4, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,249 (8.79 KB)
#  Trainable params: 2,249 (8.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cnn.compile(loss='mean_squared_error', optimizer='nadam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1, patience=2, verbose=2, mode='auto')
checkpointer = ModelCheckpoint(filepath="CNN_Parameters.hdf5.keras", verbose=0, save_best_only=True) # save best model # also file path should end in ".keras" depending on the version and environment running the keras

# %%
history = cnn.fit(x_train,y_train,validation_split=0.2,batch_size = 128, callbacks=[checkpointer],verbose=1,epochs = 100)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1196 - val_loss: 7.1297e-04
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0563 - val_loss: 4.0955e-04
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0341 - val_loss: 3.5823e-04
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0267 - val_loss: 4.3037e-04
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0195 - val_loss: 4.0025e-04
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179 - val_loss: 3.2169e-04
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0161 - val_loss: 3.1840e-04
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - val_loss: 3.3871e-04
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0148 - val_loss: 3.3790e-04
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0142 - val_loss: 2.9830e-04
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0116 - val_loss: 3.3302e-04
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - val_loss: 4.1970e-04
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110 - val_loss: 2.8356e-04
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - val_loss: 3.1904e-04
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109 - val_loss: 3.1950e-04
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - val_loss: 2.8558e-04
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095 - val_loss: 2.7751e-04
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 3.3381e-04
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090 - val_loss: 2.8036e-04
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 3.1035e-04
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 2.9789e-04
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - val_loss: 3.6905e-04
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 3.0859e-04
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076 - val_loss: 3.6202e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 3.4665e-04
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 3.0018e-04
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0065 - val_loss: 3.4714e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - val_loss: 3.5287e-04
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070 - val_loss: 3.1485e-04
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - val_loss: 3.2554e-04
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - val_loss: 2.9752e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 2.8291e-04
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - val_loss: 3.2974e-04
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 3.2400e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 3.1244e-04
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - val_loss: 4.5543e-04
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066 - val_loss: 3.2606e-04
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - val_loss: 3.7098e-04
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 4.3755e-04
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - val_loss: 6.3215e-04
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058 - val_loss: 3.2628e-04
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - val_loss: 4.7262e-04
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - val_loss: 4.9324e-04
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - val_loss: 4.2815e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - val_loss: 6.5695e-04
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 3.8260e-04
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 4.0090e-04
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - val_loss: 4.7818e-04
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 5.1381e-04
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - val_loss: 8.2234e-04
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - val_loss: 3.5430e-04
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - val_loss: 4.2773e-04
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - val_loss: 3.6573e-04
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 5.0469e-04
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - val_loss: 4.3586e-04
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - val_loss: 4.6074e-04
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - val_loss: 6.7501e-04
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - val_loss: 4.0025e-04
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 4.2765e-04
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - val_loss: 4.7111e-04
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - val_loss: 3.3192e-04
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - val_loss: 3.7567e-04
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - val_loss: 4.0022e-04
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - val_loss: 5.1881e-04
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - val_loss: 6.7790e-04
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - val_loss: 5.5693e-04
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 5.2134e-04
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 5.6336e-04
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 8.5418e-04
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - val_loss: 4.3783e-04
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - val_loss: 4.5329e-04
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - val_loss: 3.9385e-04
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - val_loss: 5.3672e-04
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - val_loss: 3.3982e-04
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - val_loss: 4.6919e-04
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - val_loss: 3.3563e-04
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 6.3028e-04
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - val_loss: 7.2127e-04
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - val_loss: 3.7871e-04
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - val_loss: 7.0519e-04
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 7.8885e-04
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - val_loss: 7.8774e-04
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - val_loss: 7.3883e-04
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - val_loss: 6.3749e-04
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - val_loss: 5.4440e-04
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 4.2010e-04
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - val_loss: 8.2231e-04
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - val_loss: 5.4247e-04
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 8.0364e-04
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 4.6319e-04
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 4.6768e-04
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - val_loss: 5.0665e-04
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 5.5531e-04
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 9.5364e-04
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 5.4154e-04
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - val_loss: 3.8344e-04
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - val_loss: 5.6080e-04
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 3.2375e-04
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 5.3169e-04

# %%
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val loss')
plt.legend()

# %%
cnn.load_weights('CNN_Parameters.hdf5.keras')

pred = cnn.predict(x_test)
print(pred.shape)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# (848, 1)

# %%
score = np.sqrt(metrics.mean_squared_error(y_test, pred))
print("RMSE Score: {}".format(score))
# Out:
# RMSE Score: 0.02033748376075988

# %%
plt.figure(figsize=(15,15))

plt.plot(y_test, label = 'actual')
plt.plot(pred,   label = 'predicted')
plt.legend()
plt.show()
